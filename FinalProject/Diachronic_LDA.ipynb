# %%
import os, pickle

import pandas as pd
import numpy as np

from lxml import etree
from tqdm.notebook import tqdm

# Modules developed by the author
from my_lda import LDA
import corpus_man as cm

pd.options.display.max_rows = 100

# %% [markdown]
# # Downloading tycho XML

# %%
# !mkdir ./corpora
# !wget --no-check-certificate http://www.tycho.iel.unicamp.br/corpus/texts/xml.zip -P ./corpora
# !mkdir ./corpora/xml
# !unzip ./corpora/xml.zip -d ./corpora/xml
# Out:
# --2022-03-22 17:43:26--  http://www.tycho.iel.unicamp.br/corpus/texts/xml.zip
# Resolving www.tycho.iel.unicamp.br (www.tycho.iel.unicamp.br)... 143.106.176.17
# Connecting to www.tycho.iel.unicamp.br (www.tycho.iel.unicamp.br)|143.106.176.17|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24196121 (23M) [application/zip]
# Saving to: ‘./corpora/xml.zip’
#
# xml.zip             100%[===================>]  23.08M  8.47MB/s    in 2.7s
#
# 2022-03-22 17:43:32 (8.47 MB/s) - ‘./corpora/xml.zip’ saved [24196121/24196121]
#
# Archive:  ./corpora/xml.zip
#   inflating: ./corpora/xml/a_001.xml
#   inflating: ./corpora/xml/a_002.xml
#   inflating: ./corpora/xml/a_003.xml
#   inflating: ./corpora/xml/a_004.xml
#   inflating: ./corpora/xml/a_005.xml
#   inflating: ./corpora/xml/a_006.xml
#   inflating: ./corpora/xml/a_007.xml
#   inflating: ./corpora/xml/a_008.xml
#   inflating: ./corpora/xml/a_009.xml
#   inflating: ./corpora/xml/b_001.xml
#   inflating: ./corpora/xml/b_002.xml
#   inflating: ./corpora/xml/b_003.xml
#   inflating: ./corpora/xml/b_005.xml
#   inflating: ./corpora/xml/b_006.xml
#   inflating: ./corpora/xml/b_007.xml
#   inflating: ./corpora/xml/b_008.xml
#   inflating: ./corpora/xml/b_009.xml
#   inflating: ./corpora/xml/b_010.xml
#   inflating: ./corpora/xml/b_011.xml
#   inflating: ./corpora/xml/c_001.xml
#   inflating: ./corpora/xml/c_002.xml
#   inflating: ./corpora/xml/c_003.xml
#   inflating: ./corpora/xml/c_004.xml
#   inflating: ./corpora/xml/c_005.xml
#   inflating: ./corpora/xml/c_006.xml
#   inflating: ./corpora/xml/c_007.xml
#   inflating: ./corpora/xml/c_008.xml
#   inflating: ./corpora/xml/c_009.xml
#   inflating: ./corpora/xml/c_010.xml
#   inflating: ./corpora/xml/d_001.xml
#   inflating: ./corpora/xml/e_001.xml
#   inflating: ./corpora/xml/f_001.xml
#   inflating: ./corpora/xml/f_002.xml
#   inflating: ./corpora/xml/f_003.xml
#   inflating: ./corpora/xml/g_001.xml
#   inflating: ./corpora/xml/g_002.xml
#   inflating: ./corpora/xml/g_003.xml
#   inflating: ./corpora/xml/g_004.xml
#   inflating: ./corpora/xml/g_005.xml
#   inflating: ./corpora/xml/g_006.xml
#   inflating: ./corpora/xml/g_008.xml
#   inflating: ./corpora/xml/g_009.xml
#   inflating: ./corpora/xml/g_010.xml
#   inflating: ./corpora/xml/g_011.xml
#   inflating: ./corpora/xml/g_012.xml
#   inflating: ./corpora/xml/h_001.xml
#   inflating: ./corpora/xml/j_001.xml
#   inflating: ./corpora/xml/l_001.xml
#   inflating: ./corpora/xml/l_002.xml
#   inflating: ./corpora/xml/m_001.xml
#   inflating: ./corpora/xml/m_003.xml
#   inflating: ./corpora/xml/m_004.xml
#   inflating: ./corpora/xml/m_005.xml
#   inflating: ./corpora/xml/m_006.xml
#   inflating: ./corpora/xml/m_007.xml
#   inflating: ./corpora/xml/m_008.xml
#   inflating: ./corpora/xml/m_009.xml
#   inflating: ./corpora/xml/m_010.xml
#   inflating: ./corpora/xml/o_001.xml
#   inflating: ./corpora/xml/o_002.xml
#   inflating: ./corpora/xml/p_001.xml
#   inflating: ./corpora/xml/p_002.xml
#   inflating: ./corpora/xml/p_003.xml
#   inflating: ./corpora/xml/p_004.xml
#   inflating: ./corpora/xml/r_001.xml
#   inflating: ./corpora/xml/s_001.xml
#   inflating: ./corpora/xml/s_002.xml
#   inflating: ./corpora/xml/s_003.xml
#   inflating: ./corpora/xml/s_004.xml
#   inflating: ./corpora/xml/s_005.xml
#   inflating: ./corpora/xml/s_006.xml
#   inflating: ./corpora/xml/s_007.xml
#   inflating: ./corpora/xml/t_001.xml
#   inflating: ./corpora/xml/v_001.xml
#   inflating: ./corpora/xml/v_002.xml
#   inflating: ./corpora/xml/v_003.xml
#   inflating: ./corpora/xml/v_004.xml
#   inflating: ./corpora/xml/v_005.xml
#   inflating: ./corpora/xml/va_001.xml
#   inflating: ./corpora/xml/va_002.xml
#   inflating: ./corpora/xml/va_003.xml
#   inflating: ./corpora/xml/va_004.xml
#   inflating: ./corpora/xml/va_006.xml
#   inflating: ./corpora/xml/va_007.xml
#   inflating: ./corpora/xml/va_008.xml
#   inflating: ./corpora/xml/va_009.xml
#   inflating: ./corpora/xml/va_010.xml
#   inflating: ./corpora/xml/va_011.xml
#   inflating: ./corpora/xml/va_012.xml

# %% [markdown]
# # Loading CSV Classification

# %% [markdown]
# The tags present in the 'period' column indicate to which period the texts belong according to Bechara's classification:
# * cont: **contemporary**
# * mod: **modern**
# * arcmed: **archaic**

# %%
df = pd.read_csv('periodos_tycho.csv',header=None)
df.columns = ['period', 'file_name']
df['genre'] = None
df['predicted_period'] = None

df['period'] = df['period'].replace(['cont1'],'cont')
df['period'] = df['period'].replace(['cont2'],'cont')

df.period.value_counts()
# Out:
# cont      48
# mod       28
# arcmed    13
# Name: period, dtype: int64

# %%
df['file_name'] = df['file_name'].apply(cm.removeMime)

# %%
df.head()
# Out:
#    period file_name genre predicted_period
# 0  arcmed     l_002  None             None
# 1  arcmed     g_009  None             None
# 2  arcmed     p_002  None             None
# 3  arcmed     b_002  None             None
# 4  arcmed     m_007  None             None

# %%
# Setting the file names as row names
new_df = df.sort_values(by='file_name').reset_index().drop('index',axis=1)
new_df = new_df.set_index('file_name')

# %%
new_df.tail(10)
# Out:
#           period genre predicted_period
# file_name
# va_002      cont  None             None
# va_003      cont  None             None
# va_004      cont  None             None
# va_006      cont  None             None
# va_007      cont  None             None
# va_008      cont  None             None
# va_009      cont  None             None
# va_010      cont  None             None
# va_011      cont  None             None
# va_012      cont  None             None

# %%
# Every xml file is parsed and the corresponding xml file is stored as
# a key value pair in the forest dict, where the key is the file name
# and the value is the parsed xml file

forest={}
for root, dirs, files in os.walk("./corpora/xml", topdown=False):
    for file_name in sorted(files):
        with open(os.path.join(root,file_name),'r') as xml:
            xml_plain = '\n'.join(xml.read().split('\n')[1:])
            try:
                forest[file_name] = etree.fromstring(xml_plain)
            except etree.XMLSyntaxError as error:
                print(error)
                print(xml_plain)
            except ValueError:
                print(xml_plain)

# %%
# id_list is a list of the files which have a assigned period from the 
# periodos_tycho.csv file
id_list = list(new_df.index)

# the tycho_to_lda file is a file where each line corresponds to a
# document from the corpus.
with open('./corpora/tycho_to_lda', 'w') as dump:
    for file_name, xml in forest.items():
        
        # get id
        for i in xml:
            if i.tag == 'head':
                name = str(i.get('id'))+'.xml'
                
        # Skipping files which don't have a period classification
        # provided by the tycho_periods.csv
        if file_name[:-4] not in id_list:
            print('not in id_lst= ',file_name)
            continue

        # get genre
        genre = cm.get_meta('Genre',xml).xpath('string()')
        new_df.loc[file_name[:-4],'genre'] = genre
    
        # get text
        text = ' '.join(xml.xpath("//body//text()"))
        # process text and write to file
        text = cm.pre_process(text)
        dump.write(text)
        dump.write('\n')

# %%
# Sanity check to see if every text was written in the tycho_to_lda file
with open('./corpora/tycho_to_lda', 'r') as dump:
    if len(dump.readlines()) == len(new_df):
        print('sanity checked!')
# Out:
# sanity checked!

# %%
new_df
# Out:
#            period                                              genre  \
# file_name
# a_001        cont                                       Dissertation
# a_002         mod                                       Dissertation
# a_003        cont                                          Narrative
# a_004        cont                                            Letters
# a_005         mod                                            Grammar
# a_006        cont                                          Narrative
# a_007         mod                                          Narrative
# a_008        cont                                            Theatre
# a_009        cont                                            Theatre
# b_001         mod                                          Narrative
# b_002      arcmed                                            Grammar
# b_003         mod                                          Narrative
# b_005        cont                                          Narrative
# b_006         mod                                          Narrative
# b_007         mod                                          Narrative
# b_008         mod                                            Letters
# b_009        cont                                            Theatre
# b_010        cont                                            Theatre
# b_011        cont                                              Songs
# c_001        cont                                            Letters
# c_002         mod                  Transcript of original manuscript
# c_003         mod                                            Letters
# c_004        cont                                            Letters
# c_005        cont                                            Theatre
# c_006         mod                                          Narrative
# c_007      arcmed                               Narrative; Chronicle
# c_008        cont                                            Theatre
# c_009        cont                                            Theatre
# c_010      arcmed                                            Theatre
# d_001      arcmed                                            Letters
# e_001        cont                                            Letters
# f_001         mod                                       Dissertation
# f_002      arcmed                                            Theatre
# f_003        cont                                            Theatre
# g_001         mod                                               News
# g_002        cont                                       Dissertation
# g_003        cont                                            Letters
# g_004        cont                                            Theatre
# g_005        cont                                          Narrative
# g_006         mod                                            Letters
# g_008      arcmed                               Narrative; Chronicle
# g_009      arcmed                               Narrative; Chronicle
# g_010        cont                                               News
# g_011        cont                                            Theatre
# g_012        cont                                            Theatre
# h_001      arcmed                                       Dissertation
# j_001        cont                                            Theatre
# l_001         mod                                          Narrative
# l_002      arcmed                                          Narrative
# m_001        cont                                            Letters
# m_003         mod                                            Letters
# m_004         mod                                          Narrative
# m_005        cont                                            Theatre
# m_006         mod                                            Theatre
# m_007      arcmed                                            Theatre
# m_008         mod                                               News
# m_009        cont                                               News
# m_010         mod                                               News
# o_001        cont                                            Letters
# o_002        cont                                          Narrative
# p_001      arcmed                                          Narrative
# p_002      arcmed  Chronica do muito alto e muito esclarecido pri...
# p_003        cont                                            Theatre
# p_004        cont                                            Theatre
# r_001         mod                                            Theatre
# s_001         mod                                          Narrative
# s_002         mod
# s_003        cont                                          Narrative
# s_004        cont                                            Theatre
# s_005         mod                                            Theatre
# s_006        cont                                            Theatre
# s_007        cont                                            Theatre
# t_001        cont                                            Theatre
# v_001        cont                                            Grammar
# v_002         mod                                            Letters
# v_003         mod                                       Dissertation
# v_004         mod                                       Dissertation
# v_005      arcmed                                            Theatre
# va_001        mod                                            Letters
# va_002       cont                                                ata
# va_003       cont                                                ata
# va_004       cont                                            Letters
# va_006       cont                                            Letters
# va_007       cont                                            Letters
# va_008       cont                                            Letters
# va_009       cont                                               News
# va_010       cont                                          Newspaper
# va_011       cont                                          Newspaper
# va_012       cont                                          Newspaper
#
#           predicted_period
# file_name
# a_001                 None
# a_002                 None
# a_003                 None
# a_004                 None
# a_005                 None
# a_006                 None
# a_007                 None
# a_008                 None
# a_009                 None
# b_001                 None
# b_002                 None
# b_003                 None
# b_005                 None
# b_006                 None
# b_007                 None
# b_008                 None
# b_009                 None
# b_010                 None
# b_011                 None
# c_001                 None
# c_002                 None
# c_003                 None
# c_004                 None
# c_005                 None
# c_006                 None
# c_007                 None
# c_008                 None
# c_009                 None
# c_010                 None
# d_001                 None
# e_001                 None
# f_001                 None
# f_002                 None
# f_003                 None
# g_001                 None
# g_002                 None
# g_003                 None
# g_004                 None
# g_005                 None
# g_006                 None
# g_008                 None
# g_009                 None
# g_010                 None
# g_011                 None
# g_012                 None
# h_001                 None
# j_001                 None
# l_001                 None
# l_002                 None
# m_001                 None
# m_003                 None
# m_004                 None
# m_005                 None
# m_006                 None
# m_007                 None
# m_008                 None
# m_009                 None
# m_010                 None
# o_001                 None
# o_002                 None
# p_001                 None
# p_002                 None
# p_003                 None
# p_004                 None
# r_001                 None
# s_001                 None
# s_002                 None
# s_003                 None
# s_004                 None
# s_005                 None
# s_006                 None
# s_007                 None
# t_001                 None
# v_001                 None
# v_002                 None
# v_003                 None
# v_004                 None
# v_005                 None
# va_001                None
# va_002                None
# va_003                None
# va_004                None
# va_006                None
# va_007                None
# va_008                None
# va_009                None
# va_010                None
# va_011                None
# va_012                None

# %% [markdown]
# On the DataFrame above we can see that the following fields are incorrect:
# * "p_002" the genre is incorrect as it has a text title.
# * "s_002" has a no genre, in the "genre" field of the XML file, while inspecting the file it was seem that the genre is a "Narrative; Chronicle".
# * Genre "ata" was not translated to english

# %%
# Fixing fields
new_df.loc['p_002','genre'] = 'Narrative; Chronicle'
new_df.loc['s_002','genre'] = 'Narrative; Chronicle'
new_df['genre'] = new_df['genre'].replace(['ata'],'Minute')

# %%
new_df['genre'].value_counts()
# Out:
# Theatre                              26
# Letters                              18
# Narrative                            17
# Dissertation                          7
# News                                  6
# Narrative; Chronicle                  5
# Grammar                               3
# Newspaper                             3
# Minute                                2
# Songs                                 1
# Transcript of original manuscript     1
# Name: genre, dtype: int64

# %% [markdown]
# # Experiments
#
# Three experiments were ran in order to analyse how the LDA would group texts and see if grouping into 3, 4 or 5 topics would yield more expressive results.

# %% [markdown]
# # 3 Topics

# %%
# Make the comparison true if you want to run the experiment, or copy the command to your favorite terminal
# emulator and run it on this same folder
# lda_cli is a CLI LDA in this folder and runs LDA with Gibbs Sampling over our documents and saves the LDA
# experiment as a class to be loaded afterwards.

if 1 == 0:
    # !python lda_cli.py -nTopics 3 -path ./corpora/tycho_to_lda -outPath ./corpora/tycho_to_lda_3
else:
    # !unzip lda_out.zip -d ./corpora/
# Out:
# Archive:  lda_out.zip
#   inflating: ./corpora/tycho_to_lda_3.out
#   inflating: ./corpora/tycho_to_lda_4.out
#   inflating: ./corpora/tycho_to_lda_5.out

# %%
# Loading the LDA class object into our notebook
with open('./corpora/tycho_to_lda_3.out', 'rb') as file:
    lda_3 = pickle.load(file)

# This method creates a dictionary which constains the most prevalent topic for each document
lda_3.classifyDocuments()

# Creates a copy of the original DataFrame
df_3topics = new_df.copy()

# Get the predicted topic grounping for each file/document
df_3topics['predicted_period'] = [lda_3.getDocTopic(i)[0] for i in range(len(new_df))]

# %%
df_3topics
# Out:
#            period                              genre  predicted_period
# file_name
# a_001        cont                       Dissertation                 2
# a_002         mod                       Dissertation                 2
# a_003        cont                          Narrative                 2
# a_004        cont                            Letters                 2
# a_005         mod                            Grammar                 0
# a_006        cont                          Narrative                 2
# a_007         mod                          Narrative                 0
# a_008        cont                            Theatre                 2
# a_009        cont                            Theatre                 1
# b_001         mod                          Narrative                 2
# b_002      arcmed                            Grammar                 0
# b_003         mod                          Narrative                 2
# b_005        cont                          Narrative                 2
# b_006         mod                          Narrative                 0
# b_007         mod                          Narrative                 0
# b_008         mod                            Letters                 2
# b_009        cont                            Theatre                 2
# b_010        cont                            Theatre                 2
# b_011        cont                              Songs                 2
# c_001        cont                            Letters                 2
# c_002         mod  Transcript of original manuscript                 0
# c_003         mod                            Letters                 2
# c_004        cont                            Letters                 2
# c_005        cont                            Theatre                 2
# c_006         mod                          Narrative                 0
# c_007      arcmed               Narrative; Chronicle                 2
# c_008        cont                            Theatre                 2
# c_009        cont                            Theatre                 2
# c_010      arcmed                            Theatre                 0
# d_001      arcmed                            Letters                 0
# e_001        cont                            Letters                 2
# f_001         mod                       Dissertation                 2
# f_002      arcmed                            Theatre                 0
# f_003        cont                            Theatre                 2
# g_001         mod                               News                 0
# g_002        cont                       Dissertation                 2
# g_003        cont                            Letters                 2
# g_004        cont                            Theatre                 2
# g_005        cont                          Narrative                 2
# g_006         mod                            Letters                 2
# g_008      arcmed               Narrative; Chronicle                 0
# g_009      arcmed               Narrative; Chronicle                 0
# g_010        cont                               News                 1
# g_011        cont                            Theatre                 1
# g_012        cont                            Theatre                 2
# h_001      arcmed                       Dissertation                 2
# j_001        cont                            Theatre                 2
# l_001         mod                          Narrative                 2
# l_002      arcmed                          Narrative                 0
# m_001        cont                            Letters                 1
# m_003         mod                            Letters                 2
# m_004         mod                          Narrative                 2
# m_005        cont                            Theatre                 2
# m_006         mod                            Theatre                 0
# m_007      arcmed                            Theatre                 0
# m_008         mod                               News                 1
# m_009        cont                               News                 1
# m_010         mod                               News                 0
# o_001        cont                            Letters                 2
# o_002        cont                          Narrative                 0
# p_001      arcmed                          Narrative                 0
# p_002      arcmed               Narrative; Chronicle                 0
# p_003        cont                            Theatre                 1
# p_004        cont                            Theatre                 2
# r_001         mod                            Theatre                 0
# s_001         mod                          Narrative                 2
# s_002         mod               Narrative; Chronicle                 0
# s_003        cont                          Narrative                 2
# s_004        cont                            Theatre                 0
# s_005         mod                            Theatre                 0
# s_006        cont                            Theatre                 2
# s_007        cont                            Theatre                 0
# t_001        cont                            Theatre                 2
# v_001        cont                            Grammar                 2
# v_002         mod                            Letters                 2
# v_003         mod                       Dissertation                 2
# v_004         mod                       Dissertation                 2
# v_005      arcmed                            Theatre                 0
# va_001        mod                            Letters                 2
# va_002       cont                             Minute                 1
# va_003       cont                             Minute                 1
# va_004       cont                            Letters                 1
# va_006       cont                            Letters                 1
# va_007       cont                            Letters                 1
# va_008       cont                            Letters                 1
# va_009       cont                               News                 1
# va_010       cont                          Newspaper                 1
# va_011       cont                          Newspaper                 1
# va_012       cont                          Newspaper                 1

# %%
# 
cm.confusionMatrix(df_3topics)
# Out:
#          0   1   2
# arcmed  11   0   2
# mod     12   1  15
# cont     3  16  29

# %% [markdown]
# ## Genres per topic grouping
# Some groups were checked to see if the LDA tried to group certain genres of texts together

# %%
genre_profile = df_3topics[df_3topics['predicted_period']==0]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#                                    genre
# Theatre                                9
# Narrative                              7
# Narrative; Chronicle                   4
# Grammar                                2
# News                                   2
# Transcript of original manuscript      1
# Letters                                1

# %%
genre_profile = df_3topics[df_3topics['predicted_period']==1]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#            genre
# Letters        5
# News           4
# Theatre        3
# Newspaper      3
# Minute         2

# %%
genre_profile = df_3topics[df_3topics['predicted_period']==2]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#                       genre
# Theatre                  14
# Letters                  12
# Narrative                10
# Dissertation              7
# Songs                     1
# Narrative; Chronicle      1
# Grammar                   1

# %% [markdown]
# ## Most frequent words per topic

# %%
pd.DataFrame(lda_3.mostFreqWordsTopic(30)).transpose()
# Out:
#               0           1       2
# 0           que         que     que
# 1           por        para     não
# 2           com         não     com
# 3           não         com    para
# 4           rey         por     por
# 5           lhe         dos    mais
# 6          como      senhor    como
# 7           naõ         uma     uma
# 8           hum         sua     lhe
# 9          para         lhe     dos
# 10          dom        mais     mas
# 11          vos         seu     sua
# 12     included         mil  porque
# 13         mais       vossa   vossa
# 14         pera        como     nos
# 15  punctuation         foi   muito
# 16       porque        elle     seu
# 17          nam       amigo     das
# 18         elle         ele     são
# 19          dos        pelo     tão
# 20          rei         tem    quem
# 21        elrey       carta     nem
# 22        muito         meu     bem
# 23          ſeu        esta     tem
# 24          ſua        está     ser
# 25          bem  excelência    esta
# 26          foy       muito     sem
# 27          ele        aqui    deus
# 28          mas         ser   todos
# 29       outros    senhoria  senhor

# %% [markdown]
# # 4 Topics

# %%
if 1 == 0:
    # !python lda_cli.py -nTopics 4 -path ./corpora/tycho_to_lda -outPath ./corpora/tycho_to_lda_4

# %%
with open('./corpora/tycho_to_lda_4.out', 'rb') as file:
    lda_4 = pickle.load(file)

lda_4.classifyDocuments()

df_4topics = new_df.copy()
df_4topics['predicted_period'] = [lda_4.getDocTopic(i)[0] for i in range(len(new_df))]

# %%
df_4topics.head()
# Out:
#           period         genre  predicted_period
# file_name
# a_001       cont  Dissertation                 1
# a_002        mod  Dissertation                 1
# a_003       cont     Narrative                 1
# a_004       cont       Letters                 1
# a_005        mod       Grammar                 2

# %%
cm.confusionMatrix(df_4topics)
# Out:
#         0   1  2   3
# arcmed  7   1  5   0
# mod     9  14  5   0
# cont    2  26  3  17

# %% [markdown]
# ## Genres per topic grouping

# %%
genre_profile = df_4topics[df_4topics['predicted_period']==0]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#                                    genre
# Narrative                              5
# Narrative; Chronicle                   5
# News                                   5
# Letters                                2
# Transcript of original manuscript      1

# %%
genre_profile = df_4topics[df_4topics['predicted_period']==1]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#               genre
# Theatre          12
# Narrative        10
# Letters          10
# Dissertation      7
# Songs             1
# Grammar           1

# %%
genre_profile = df_4topics[df_4topics['predicted_period']==2]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#            genre
# Theatre        9
# Grammar        2
# Narrative      2

# %%
genre_profile = df_4topics[df_4topics['predicted_period']==3]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#            genre
# Letters        6
# Theatre        5
# Newspaper      3
# Minute         2
# News           1

# %% [markdown]
# ## Most frequent words per topic

# %%
pd.DataFrame(lda_4.mostFreqWordsTopic(30)).transpose()
# Out:
#          0       1            2           3
# 0      que     que          que         que
# 1      com     não          não         não
# 2      por     com          por        para
# 3      rey    para     included         com
# 4      lhe     por          naõ         por
# 5     para    mais  punctuation      senhor
# 6     como    como          com         dos
# 7      rei     uma         como         uma
# 8      dos     lhe          nam         lhe
# 9      hum     mas          lhe         sua
# 10    pera     dos          vos        mais
# 11     dom   vossa       porque       vossa
# 12     sua  porque         para        elle
# 13    mais     sua          hum        como
# 14   elrey     nos         mais       amigo
# 15     seu     das       mestre         seu
# 16     não     seu          dom         foi
# 17   muito   muito          mas         meu
# 18     naõ     são         quem         mil
# 19     mil     tão    discípulo         ele
# 20    elle    quem          bem       muito
# 21   conde     nem         pois        aqui
# 22     era     bem         elle  excelência
# 23     foi     ser          tem       carta
# 24     vos     tem         pera        pelo
# 25     foy     sem          ele         tem
# 26     das    deus         eſta       minha
# 27  porque    esta          vós    senhoria
# 28  grande   ainda       outros        esta
# 29   todos  quando         eſte       pedro

# %% [markdown]
# # 5 Topics

# %%
if 1 == 0:
    # !python lda_cli.py -nTopics 5 -path ./corpora/tycho_to_lda -outPath ./corpora/tycho_to_lda_5

# %%
with open('./corpora/tycho_to_lda_5.out', 'rb') as file:
    lda_5 = pickle.load(file)

lda_5.classifyDocuments()

df_5topics = new_df.copy()
df_5topics['predicted_period'] = [lda_5.getDocTopic(i)[0] for i in range(len(new_df))]

# %%
cm.confusionMatrix(df_5topics)
# Out:
#         0  1   2  3   4
# arcmed  6  5   1  1   0
# mod     8  4  15  1   0
# cont    2  3   9  7  27

# %% [markdown]
# ## Genres per topic grouping

# %%
genre_profile = df_5topics[df_5topics['predicted_period']==0]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#                                    genre
# Narrative                              5
# News                                   5
# Narrative; Chronicle                   4
# Transcript of original manuscript      1
# Letters                                1

# %%
genre_profile = df_5topics[df_5topics['predicted_period']==1]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#                       genre
# Theatre                   9
# Narrative                 2
# Narrative; Chronicle      1

# %%
genre_profile = df_5topics[df_5topics['predicted_period']==2]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#               genre
# Letters          10
# Dissertation      7
# Narrative         6
# Songs             1
# Grammar           1

# %%
genre_profile = df_5topics[df_5topics['predicted_period']==3]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#          genre
# Letters      5
# Grammar      2
# Minute       2

# %%
genre_profile = df_5topics[df_5topics['predicted_period']==4]
pd.DataFrame(genre_profile['genre'].value_counts())
# Out:
#            genre
# Theatre       17
# Narrative      4
# Newspaper      3
# Letters        2
# News           1

# %% [markdown]
# ## Most frequent words per topic

# %%
pd.DataFrame(lda_5.mostFreqWordsTopic(30)).transpose()
# Out:
#          0            1       2           3       4
# 0      que          que     que         que     que
# 1      com          não     não         com     não
# 2      por     included     com         por    para
# 3      rey          por     por         não     uma
# 4      lhe          naõ    para        para     com
# 5     para  punctuation    mais      senhor     por
# 6      rei          com    como       vossa     mas
# 7      hum          nam     dos         lhe  senhor
# 8      dom          vos     lhe         dos    como
# 9      dos         como   vossa       amigo     meu
# 10    como          lhe     sua        como    está
# 11     sua          hum  porque        elle     lhe
# 12   elrey         para     uma        mais     ele
# 13     naõ          dom     mas   discípulo    mais
# 14    pera         mais     nos      mestre   minha
# 15     mil          mas     das       carta     dos
# 16    elle       porque     são    senhoria   maria
# 17     seu          bem     seu  excelência     tem
# 18   conde         quem   muito         sua     seu
# 19    mais         pois     tão      margem     sua
# 20   muito         pera     nem        esta    elle
# 21     foy         eſte    deus         foi     foi
# 22     era         eſta    esta         ele   muito
# 23     foi          meu    quem       socio     ela
# 24    huma          ſer     sem         amo     vai
# 25     vos       outros     ser        senr    isso
# 26  grande          ſeu   todos        aqui   parte
# 27     das         elle     bem         exa     bem
# 28   reyno          vós   assim         tem   pedro
# 29  porque          ſua   ainda         seu    casa
